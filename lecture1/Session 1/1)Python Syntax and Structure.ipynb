# %% [markdown]
# # Getting Started with Python

# %% [markdown]
# There are 2 common ways to install Python:
#
# 1. **Official Installer (python.org)**
# 2. **Anaconda Distribution**

# %% [markdown]
# ```bash
# For Windows:
# 1)Run the downloaded .exe installer
# 2)Check the box "Add Python to PATH"
# 3)Click on "Install Now"
# 4)Wait for the installation to complete
#
# For macOS:
# 1)Run the .pkg file downloaded
# 2)Agree & Follow the instructions to install
# ```

# %%
# !python --version
# !pip --version
# Out:
# Python 3.12.7
# pip 25.1.1 from C:\Users\aamir\AppData\Roaming\Python\Python312\site-packages\pip (python 3.12)

# %% [markdown]
# ## 2. Writing Your First Python Script
#
# Create a file called `hello.py`:
#
# ```python
# print('Hello, world!')
# ```
#
# Run it from the command line:
#
# ```bash
# python hello.py
# ```

# %%
print('Hello, world!')
# Out:
# Hello, world!

# %% [markdown]
# ## 3. Python Indentation Rules
#
# - Blocks are defined by **indentation**, not braces.

# %%
if 1!=2:
 print("Hello ji")
# Out:
# Hello ji

# %%
if 1!=2:
print("Hello ji")
# Out:
#   Cell In[7], line 2
#     print("Hello ji")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
if 1!=2:
    print("Hello ji")
# Out:
# Hello ji

# %% [markdown]
# ## 4. Comments and Docstrings
#
# - `#` starts a single‑line comment.
# - Triple quotes (`"""` or `'''`) placed as the **first** statement in a module, function, or class become the **docstring**.

# %%
#Hello ji

# %%
"""Hello and welcome dosto to
5 Minutes Engineering
----------
Kaise ho
Sab badiya"""
# Out:
# 'Hello and welcome dosto to\n5 Minutes Engineering\n----------\nKaise ho\nSab badiya'

# %% [markdown]
# ## 5. Running Scripts via Command Line and IDE
#
# ### Command Line
#
# ```bash
# python myscript.py
# ```
#
# ### Popular IDEs / Editors
#
# - **VS Code**
# - **Jupyter Notebook / JupyterLab**
