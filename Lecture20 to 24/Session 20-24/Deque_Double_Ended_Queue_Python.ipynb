# %% [markdown]
# ## 1. Insert/Delete from Both Ends

# %%
from collections import deque

dq = deque()
dq.append(1)        
dq.appendleft(0)    
print("After insertions:", list(dq))

dq.pop()            
dq.popleft()     
print("After deletions:", list(dq))
# Out:
# After insertions: [0, 1]
# After deletions: []

# %% [markdown]
# ## 2. Python `collections.deque` Usage

# %%
dq = deque([1, 2, 3])
dq.append(4)          
dq.appendleft(0)    
print("Deque:", dq)

dq.pop()              
dq.popleft()     
print("Modified Deque:", dq)
# Out:
# Deque: deque([0, 1, 2, 3, 4])
# Modified Deque: deque([1, 2, 3])

# %% [markdown]
# ## 3. Applications
# ### a. Sliding Window Maximum (Using Deque)

# %%
def sliding_window_maximum(nums, k):
    from collections import deque
    dq = deque()
    result = []

    for i in range(len(nums)):
        if dq and dq[0] == i - k:
            dq.popleft()

        while dq and nums[dq[-1]] < nums[i]:
            dq.pop()

        dq.append(i)

        if i >= k - 1:
            result.append(nums[dq[0]])

    return result

print("Sliding window maximum:", sliding_window_maximum([1,3,-1,-3,5,3,6,7], 3))
# Out:
# Sliding window maximum: [3, 3, 5, 5, 6, 7]

# %% [markdown]
# ### b. Palindrome Checking using Deque

# %%
def is_palindrome(s):
    dq = deque(s)
    while len(dq) > 1:
        if dq.popleft() != dq.pop():
            return False
    return True

print("Is 'racecar' a palindrome?", is_palindrome("racecar"))
print("Is 'hello' a palindrome?", is_palindrome("hello"))
# Out:
# Is 'racecar' a palindrome? True
# Is 'hello' a palindrome? False
