# %% [markdown]
# ## 1. Counter

# %%
from collections import Counter

data = "Shridhar"
counter = Counter(data)

print(counter)
# Out:
# Counter({'h': 2, 'r': 2, 'S': 1, 'i': 1, 'd': 1, 'a': 1})

# %% [markdown]
# ## 2. deque

# %%
from collections import deque

dq = deque([1, 2, 3])
dq.append(4) 
dq.appendleft(0)  

print(dq)

dq.pop() 
dq.popleft()

print(dq)
# Out:
# deque([0, 1, 2, 3, 4])
# deque([1, 2, 3])

# %% [markdown]
# ## 3. OrderedDict

# %%
from collections import OrderedDict

ordered_dict = OrderedDict([('apple', 1), ('banana', 2), ('cherry', 3)])

ordered_dict['date'] = 4

print(ordered_dict)

print(ordered_dict.popitem(last=False))
# Out:
# OrderedDict([('apple', 1), ('banana', 2), ('cherry', 3), ('date', 4)])
# ('apple', 1)

# %% [markdown]
# ## 4. defaultdict

# %%
from collections import defaultdict

dd = defaultdict(list)
dd['fruits'].append('apple')
dd['fruits'].append('banana')

print(dd)
# Out:
# defaultdict(<class 'list'>, {'fruits': ['apple', 'banana']})

# %% [markdown]
# ## 5. ChainMap

# %%
from collections import ChainMap

dict1 = {'a': 1, 'b': 2}
dict2 = {'b': 3, 'c': 4}

combined = ChainMap(dict1, dict2)

print(combined)

print(combined['b'])
# Out:
# ChainMap({'a': 1, 'b': 2}, {'b': 3, 'c': 4})
# 2

# %% [markdown]
# ## 6. namedtuple

# %%
from collections import namedtuple

Point = namedtuple('Point', ['x', 'y'])

p = Point(1, 2)
print(p)

print(p.x, p.y)
# Out:
# Point(x=1, y=2)
# 1 2
