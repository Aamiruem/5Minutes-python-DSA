# %%
dict1 = {"name": "kamran", "rollno": 5, "PASS": True}

# %%
dict1
# Out:
# {'name': 'kamran', 'rollno': 5, 'PASS': True}

# %%
dict2 = {"name": "xyz", "name": "abc"}

# %%
dict2
# Out:
# {'name': 'abc'}

# %%
dict1["name"]
# Out:
# 'kamran'

# %%
dict3 = {
    "sports_id": 1,
    "sports_name": "cricket",
    "score1": [20, 40, 70, 2],
    "score2": (1, 2, 3, 4, 5),
    "score3": {10, 20, 30, 40, 50},
}

print(dict3)
# Out:
# {'sports_id': 1, 'sports_name': 'cricket', 'score1': [20, 40, 70, 2], 'score2': (1, 2, 3, 4, 5), 'score3': {50, 20, 40, 10, 30}}

# %%
import pandas as pd
import numpy as np

# Option 1: With infer_objects (Recommended)
df = (
    pd.DataFrame({"A": [1, 2, None], "B": ["x", None, "z"]})
    .fillna(value=np.nan)
    .infer_objects(copy=False)
)

# Option 2: With future option set
pd.set_option("future.no_silent_downcasting", True)
df = pd.DataFrame({"A": [1, 2, None], "B": ["x", None, "z"]}).fillna(value=np.nan)

# %%
dict3
# Out:
# {'sports_id': 1,
#  'sports_name': 'cricket',
#  'score1': [20, 40, 70, 2],
#  'score2': (1, 2, 3, 4, 5),
#  'score3': {10, 20, 30, 40, 50}}

# %%
dict4 = dict(product_id=1, product_name="xyz", product_price=999)

# %%
dict4
# Out:
# {'product_id': 1, 'product_name': 'xyz', 'product_price': 999}

# %%
dict3.keys()
# Out:
# dict_keys(['sports_id', 'sports_name', 'score1', 'score2', 'score3'])

# %%
dict3["win"] = True

# %%
dict3.keys()
# Out:
# dict_keys(['sports_id', 'sports_name', 'score1', 'score2', 'score3', 'win'])

# %%
dict3.values()
# Out:
# dict_values([1, 'cricket', [20, 40, 70, 2], (1, 2, 3, 4, 5), {50, 20, 40, 10, 30}, True])

# %%
dict3["win"] = False

# %%
dict3.values()  # This will update the value of the key "win" to False. The keys of the dictionary will remain the same, but the value associated with the key "win" will be updated to False.
# Out:
# dict_values([1, 'cricket', [20, 40, 70, 2], (1, 2, 3, 4, 5), {50, 20, 40, 10, 30}, False])

# %%
dict3.items()
# Out:
# dict_items([('sports_id', 1), ('sports_name', 'cricket'), ('score1', [20, 40, 70, 2]), ('score2', (1, 2, 3, 4, 5)), ('score3', {50, 20, 40, 10, 30}), ('win', False)])

# %%
dict3.update(
    {"win": True}
)  # This will update the value of the key "win" to True. If the key "win" does not exist in the dictionary, it will be added with the value True.

# %%
dict4 = dict3.copy()  # This will create a new dictionary dict4 that is a copy of dict3. Any changes made to dict4 will not affect dict3, and vice versa.
dict4
# Out:
# C:\Users\My Pc\AppData\Local\Temp\ipykernel_16676\1285569295.py:306: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   }, orient="index").transpose().fillna(value=np.nan)
# {'sports_id': 1,
#  'sports_name': 'cricket',
#  'score1': [20, 40, 70, 2],
#  'score2': (1, 2, 3, 4, 5),
#  'score3': {10, 20, 30, 40, 50},
#  'win': True}

# %%
dict3
# Out:
# C:\Users\My Pc\AppData\Local\Temp\ipykernel_16676\1285569295.py:306: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   }, orient="index").transpose().fillna(value=np.nan)
# {'sports_id': 1,
#  'sports_name': 'cricket',
#  'score1': [20, 40, 70, 2],
#  'score2': (1, 2, 3, 4, 5),
#  'score3': {10, 20, 30, 40, 50},
#  'win': True}

# %%
dict3.pop(
    "win"
)  # This will remove the key "win" and its associated value from the dictionary and return the value that was removed. In this case, it will return True.
# Out:
# True

# %%
dict3
# Out:
# C:\Users\My Pc\AppData\Local\Temp\ipykernel_16676\1285569295.py:306: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   }, orient="index").transpose().fillna(value=np.nan)
# {'sports_id': 1,
#  'sports_name': 'cricket',
#  'score1': [20, 40, 70, 2],
#  'score2': (1, 2, 3, 4, 5),
#  'score3': {10, 20, 30, 40, 50}}

# %%
dict3.popitem()  # This will remove and return the last inserted key-value pair from the dictionary. In this case, it will remove the key "score3" and its associated value.
# Out:
# ('score3', {10, 20, 30, 40, 50})

# %%
dict3
# Out:
# C:\Users\My Pc\AppData\Local\Temp\ipykernel_16676\1285569295.py:306: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   }, orient="index").transpose().fillna(value=np.nan)
# {'sports_id': 1,
#  'sports_name': 'cricket',
#  'score1': [20, 40, 70, 2],
#  'score2': (1, 2, 3, 4, 5)}

# %%
del dict3[
    "score2"
]  # This will delete the key "score2" and its associated value from the dictionary.

# %%
dict3
# Out:
# {'sports_id': 1, 'sports_name': 'cricket', 'score1': [20, 40, 70, 2]}

# %%
dict3.clear()  # This will remove all the key-value pairs from the dictionary, leaving it empty.

# %%
dict3
# Out:
# {}

# %%
del (
    dict3
)  # This will delete the entire dictionary and we won't be able to access it anymore.

# %%
dict3  # This will raise an error because dict3 has been deleted and is no longer accessible.  # noqa: F821
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 dict3  # This will raise an error because dict3 has been deleted and is no longer accessible.  # noqa: F821
#
# NameError: name 'dict3' is not defined

# %%
dict3 = {
    "sports_id": 1,
    "sports_name": "cricket",
    "score1": [20, 40, 70, 2],
    "score2": (1, 2, 3, 4, 5),
    "score3": {10, 20, 30, 40, 50},
}

# %%
dict3
# Out:
# {'sports_id': 1,
#  'sports_name': 'cricket',
#  'score1': [20, 40, 70, 2],
#  'score2': (1, 2, 3, 4, 5),
#  'score3': {10, 20, 30, 40, 50}}
