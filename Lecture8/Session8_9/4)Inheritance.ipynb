# %% [markdown]
# ## 1. Single Inheritance: Base and Derived Classes
# * The child class inherits methods and attributes from the parent.
# * Promotes code reuse and specialization.

# %%
class Animal:
    def speak(self):
        return "I am an animal"

class Dog(Animal):
    def bark(self):
        return "Woof!"

d = Dog()
print(d.speak())
print(d.bark())
# Out:
# I am an animal
# Woof!

# %% [markdown]
# ## 2. Method Overriding
# * Child class redefines a method from the parent.
# * Allows customization of behavior.

# %%
class Animal:
    def speak(self):
        return "Animal speaks"

class Cat(Animal):
    def speak(self):
        return "Meow!"

c = Cat()
print(c.speak())
# Out:
# Meow!

# %%
class Catt(Animal):
    pass

c = Catt()
print(c.speak())
# Out:
# Animal speaks

# %% [markdown]
# ## 3. Using `super()` to Call Parent Methods
# * `super()` gives access to the parent class's methods.
# * Useful when extending parent logic.

# %%
class Person:
    def __init__(self, name):
        self.name = name

class Student(Person):
    def __init__(self, name, grade):
        super().__init__(name)
        self.grade = grade

s = Student("Asha", "A+")
print(s.name, s.grade)
# Out:
# Asha A+

# %% [markdown]
# ## 4. Multi-level and Hierarchical Inheritance
# **Multi-level**: Grandchild inherits from Child, which inherits from Parent.
# **Hierarchical**: Multiple child classes from a single parent.

# %%
# Multi-level Inheritance
class A:
    def method_a(self): return "A"

class B(A):
    def method_b(self): return "B"

class C(B):
    def method_c(self): return "C"

c = C()
print(c.method_a(), c.method_b(), c.method_c())
# Out:
# A B C

# %%
# Hierarchical Inheritance
class Parent:
    def show(self): return "Parent"

class Child1(Parent): pass
class Child2(Parent): pass

print(Child1().show())
print(Child2().show())
# Out:
# Parent
# Parent

# %%
c1 = Child1()
c2 = Child2()
print(c1.show())
print(c2.show())
# Out:
# Parent
# Parent

# %% [markdown]
# ## 5. Python's Support for Multiple Inheritance

# %%
class Flyer:
    def fly(self): return "I can fly"

class Swimmer:
    def swim(self): return "I can swim"

class Duck(Flyer, Swimmer): pass

d = Duck()
print(d.fly())
print(d.swim())
# Out:
# I can fly
# I can swim

# %% [markdown]
# ## 6. MRO (Method Resolution Order)
# Left-to-right in the inheritance list: D(B, C)

# %%
class A: pass
class B(A): pass
class C(A): pass
class D(B, C): pass

print(D.__mro__)
# Out:
# (<class '__main__.D'>, <class '__main__.B'>, <class '__main__.C'>, <class '__main__.A'>, <class 'object'>)
