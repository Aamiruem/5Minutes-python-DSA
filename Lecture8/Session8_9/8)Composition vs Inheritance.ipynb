# %% [markdown]
# ## 1. Composition: The *has‑a* Relationship

# %%
class A:
    def __init__(self, abc):
        self.abc = abc
    def fun1(self):
        return f"Class A : {self.abc}"
    
class B:
     def __init__(self, xyz, abc):
        self.xyz = xyz
        self.A = A(abc)
     def fun2(self):
        return f"Class B : {self.xyz}--->{self.A.fun1()}"
    
b = B('Shridhar', 5)
print(b.fun2())
# Out:
# Class B : Shridhar--->Class A : 5

# %%
class Engine:
    def __init__(self, horsepower):
        self.horsepower = horsepower
    def start(self):
        return f"Engine with {self.horsepower} HP roars to life!"

class Car:
    def __init__(self, brand, hp):
        self.brand = brand
        self.engine = Engine(hp)
    def drive(self):
        return f"{self.brand} driving... {self.engine.start()}"

c = Car('Tesla', 670)
print(c.drive())
# Out:
# Tesla driving... Engine with 670 HP roars to life!

# %% [markdown]
# ## 2. Inheritance: The *is‑a* Relationship

# %%
class Animal:
    def speak(self):
        return "(generic sound)"

class Dog(Animal):
    def speak(self):
        return "Woof!"

class Cat(Animal):
    def speak(self):
        return "Meow!"

for pet in (Dog(), Cat()):
    print(pet.speak())
# Out:
# Woof!
# Meow!
