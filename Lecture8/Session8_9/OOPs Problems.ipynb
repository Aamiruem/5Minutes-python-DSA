# %% [markdown]
# ## 1. Problem (Polymorphism)
# Implement a function process_payment(payment_method, amount) that takes any valid payment method object and an amount, and processes the payment accordingly.
#
# Each payment method (like CreditCard or UPI) should define its own pay() method with custom logic for printing how the payment is made.

# %%
class CreditCard:
    def pay(self, amount):
        print(f"Paid {amount} using Credit Card.")

class UPI:
    def pay(self, amount):
        print(f"Paid {amount} using UPI.")

def process_payment(payment_method, amount):
    payment_method.pay(amount)

process_payment(CreditCard(), 1000)
process_payment(UPI(), 500)
# Out:
# Paid 1000 using Credit Card.
# Paid 500 using UPI.

# %% [markdown]
# ## 2. Problem (Encapsulation)
# Design a BankAccount class that encapsulates the account balance and provides secure methods for depositing and withdrawing money. Ensure the balance cannot be accessed or modified directly from outside the class.

# %%
class BankAccount:
    def __init__(self, owner):
        self.owner = owner
        self.__balance = 0

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
        else:
            print("Invalid deposit!")

    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
        else:
            print("Insufficient balance!")

    @property
    def bal(self):
        return self.__balance

acc = BankAccount("Shridhar")
acc.deposit(5000)
acc.withdraw(1500)
print("Balance:", acc.bal)
# Out:
# Balance: 3500

# %% [markdown]
# ## 3. Problem (Inheritance)
# Create a base class Shape that enforces the presence of an area() method in all its subclasses. Implement specific shapes like Rectangle and Circle that inherit from Shape and define their own area calculation logic.

# %%
import math

class Shape:
    def area(self):
        raise NotImplementedError("Subclass must implement area method")


class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width


class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2


r = Rectangle(4, 5)
c = Circle(3)

print(f"Rectangle area: {r.area()}")
print(f"Circle area: {c.area():.2f}")
# Out:
# Rectangle area: 20
# Circle area: 28.27

# %%
import math
from abc import ABC, abstractmethod
class Shape(ABC):
     @abstractmethod
     def area(self):
         pass


class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width


class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2


r = Rectangle(4, 5)
c = Circle(3)

print(f"Rectangle area: {r.area()}")
print(f"Circle area: {c.area():.2f}")
# Out:
# Rectangle area: 20
# Circle area: 28.27
