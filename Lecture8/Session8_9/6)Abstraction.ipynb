# %% [markdown]
# ## 1. Hiding Implementation Details

# %%
class _Helper:
    def _operate(self):
        return "Doing hidden work"

class PublicAPI:
    def __init__(self):
        self.__helper = _Helper()

    def perform(self):
        return self.__helper._operate()

api = PublicAPI()
print(api.perform())

try:
    print(api.__helper)
except AttributeError as e:
    print("Hidden attribute!", e)
# Out:
# Doing hidden work
# Hidden attribute! 'PublicAPI' object has no attribute '__helper'

# %% [markdown]
# ## 2. Abstract Base Classes (`abc` module) & @abstractmethod
# * Provide a way to define **interfaces**.

# %%
from abc import ABC, abstractmethod

class Vehicle(ABC):
    @abstractmethod
    def move(self):
        pass

class Car(Vehicle):
    def move(self):
        return "Car drives on road"

class Bicycle(Vehicle):
    def move(self):
        return "Bicycle pedals on road"

for v in (Car(), Bicycle()):
    print(v.move())
# Out:
# Car drives on road
# Bicycle pedals on road

# %% [markdown]
# ## 3. Designing Interfaces & Base Templates

# %%
class PaymentProcessor(ABC):
    @abstractmethod
    def pay(self, amount):
        pass

class CreditCardProcessor(PaymentProcessor):
    def pay(self, amount):
        print(f"Paid ₹{amount} via Credit Card")

class UPIProcessor(PaymentProcessor):
    def pay(self, amount):
        print(f"Paid ₹{amount} via UPI")

def checkout(processor: PaymentProcessor, amount):
    processor.pay(amount)

checkout(CreditCardProcessor(), 2500)
checkout(UPIProcessor(), 950)
# Out:
# Paid ₹2500 via Credit Card
# Paid ₹950 via UPI
