# %%
tuple_x = (10, 203, 40, 56, 67, 34, 78)
print(tuple_x)
# Out:
# (10, 203, 40, 56, 67, 34, 78)

# %%
type(tuple_x)
# Out:
# tuple

# %%
# what all data types are supported inside the tuple
tuple_data = (12, 6.7, "apple", True, None, [1, 2, 3, 4, 5])
tuple_data[2]
# Out:
# 'apple'

# %%
# tuple is type of non primitive data type and follows almost same properties to as that of list but also contains some major difference.
# we can also declare all types of data inide the tuple and it also follows indexing.
