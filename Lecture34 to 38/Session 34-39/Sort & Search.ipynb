# %% [markdown]
# ### Bubble Sort

# %%
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(n - i - 1): 
            if arr[j] > arr[j + 1]:
                print("Swap-->",arr[j],"<-->",arr[j+1])
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
    return arr

print(bubble_sort([5, 2, 9, 1, 5]))
# Out:
# Swap--> 5 <--> 2
# Swap--> 9 <--> 1
# Swap--> 9 <--> 5
# Swap--> 5 <--> 1
# Swap--> 2 <--> 1
# [1, 2, 5, 5, 9]

# %% [markdown]
# ### Selection Sort

# %%
def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_idx = i
        for j in range(i + 1, n):
            if arr[j] < arr[min_idx]:
                print("min-->",min_idx)
                min_idx = j
        arr[i], arr[min_idx] = arr[min_idx], arr[i] 
    return arr

print(selection_sort([5, 2, 9, 1, 5]))
# Out:
# min--> 0
# min--> 1
# min--> 2
# min--> 3
# [1, 2, 5, 5, 9]

# %% [markdown]
# ### Insertion Sort

# %%
def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1
        while j >= 0 and arr[j] > key:
            arr[j + 1] = arr[j]  
            j -= 1
        arr[j + 1] = key
    return arr

print(insertion_sort([5, 2, 9, 1, 5]))
# Out:
# [1, 2, 5, 5, 9]

# %% [markdown]
# ## Counting Sort

# %%
def counting_sort(arr):
    max_val = max(arr)
    count = [0] * (max_val + 1)
    
    for num in arr:
        count[num] += 1
    
    result = []
    for i, c in enumerate(count):
        print(i,"-->",c)
        result.extend([i] * c)
        print("Result", result)
    return result

print(counting_sort([5, 2, 9, 1, 6, 5]))
# Out:
# 0 --> 0
# Result []
# 1 --> 1
# Result [1]
# 2 --> 1
# Result [1, 2]
# 3 --> 0
# Result [1, 2]
# 4 --> 0
# Result [1, 2]
# 5 --> 2
# Result [1, 2, 5, 5]
# 6 --> 1
# Result [1, 2, 5, 5, 6]
# 7 --> 0
# Result [1, 2, 5, 5, 6]
# 8 --> 0
# Result [1, 2, 5, 5, 6]
# 9 --> 1
# Result [1, 2, 5, 5, 6, 9]
# [1, 2, 5, 5, 6, 9]

# %% [markdown]
# ## Merge Sort

# %%
def merge_sort(arr):
    if len(arr) <= 1:
        return arr
    
    mid = len(arr) // 2
    left = merge_sort(arr[:mid])   
    right = merge_sort(arr[mid:])  
    
    return merge(left, right)

def merge(left, right):
    result = []
    i = j = 0
    
    while i < len(left) and j < len(right):
        if left[i] <= right[j]:
            result.append(left[i]); i += 1
        else:
            result.append(right[j]); j += 1
    
    result.extend(left[i:])   
    result.extend(right[j:])
    return result

print(merge_sort([5, 2, 9, 1, 5, 6]))
# Out:
# [1, 2, 5, 5, 6, 9]

# %% [markdown]
# ## Quick Sort

# %%
def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    
    pivot = arr[len(arr) // 2]  
    left = [x for x in arr if x < pivot]
    mid  = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    
    return quick_sort(left) + mid + quick_sort(right)

print(quick_sort([5, 2, 9, 1, 5, 6]))
# Out:
# [1, 2, 5, 5, 6, 9]

# %% [markdown]
# ## Heap Sort

# %%
def heapify(arr, n, i):
    largest = i
    l, r = 2*i + 1, 2*i + 2
    
    if l < n and arr[l] > arr[largest]:
        largest = l
    if r < n and arr[r] > arr[largest]:
        largest = r
    
    if largest != i:
        arr[i], arr[largest] = arr[largest], arr[i]
        heapify(arr, n, largest)

def heap_sort(arr):
    n = len(arr)
    for i in range(n//2 - 1, -1, -1):
        heapify(arr, n, i)
    for i in range(n-1, 0, -1):
        arr[0], arr[i] = arr[i], arr[0]  
        heapify(arr, i, 0)
    return arr

print(heap_sort([5, 2, 9, 1, 5, 6]))
# Out:
# [1, 2, 5, 5, 6, 9]

# %% [markdown]
# ## Counting Sort

# %%
def counting_sort(arr):
    max_val = max(arr)
    count = [0] * (max_val + 1)
    
    for num in arr:
        count[num] += 1
    
    result = []
    for i, c in enumerate(count):
        print(i,"-->",c)
        result.extend([i] * c)
        print("Result", result)
    return result

print(counting_sort([5, 2, 9, 1, 6, 5]))
# Out:
# 0 --> 0
# Result []
# 1 --> 1
# Result [1]
# 2 --> 1
# Result [1, 2]
# 3 --> 0
# Result [1, 2]
# 4 --> 0
# Result [1, 2]
# 5 --> 2
# Result [1, 2, 5, 5]
# 6 --> 1
# Result [1, 2, 5, 5, 6]
# 7 --> 0
# Result [1, 2, 5, 5, 6]
# 8 --> 0
# Result [1, 2, 5, 5, 6]
# 9 --> 1
# Result [1, 2, 5, 5, 6, 9]
# [1, 2, 5, 5, 6, 9]

# %% [markdown]
# ## Radix Sort

# %%
def counting_sort_digit(arr, exp):
    n = len(arr)
    output = [0] * n
    count = [0] * 10
    
    for num in arr:
        index = (num // exp) % 10
        count[index] += 1
    
    for i in range(1, 10):
        count[i] += count[i-1]
    
    for i in range(n-1, -1, -1):
        index = (arr[i] // exp) % 10
        output[count[index] - 1] = arr[i]
        count[index] -= 1
    
    for i in range(n):
        arr[i] = output[i]

def radix_sort(arr):
    max_val = max(arr)
    exp = 1
    while max_val // exp > 0:
        counting_sort_digit(arr, exp)
        exp *= 10
    return arr

print(radix_sort([170, 45, 75, 90, 802, 24, 2, 66]))
# Out:
# [2, 24, 45, 66, 75, 90, 170, 802]

# %% [markdown]
# ## Bucket Sort

# %%
def bucket_sort(arr):
    buckets = [[] for _ in range(len(arr))]
    
    for num in arr:
        index = int(num * len(arr)) 
        buckets[index].append(num)
    
    for b in buckets:
        b.sort()
    
    result = []
    for b in buckets:
        result.extend(b)
    return result

print(bucket_sort([0.78, 0.17, 0.39, 0.26, 0.72, 0.94, 0.21, 0.12, 0.23, 0.68]))
# Out:
# [0.12, 0.17, 0.21, 0.23, 0.26, 0.39, 0.68, 0.72, 0.78, 0.94]

# %% [markdown]
# ## Advanced Binary Search Variants

# %%
def lower_bound(arr, target):
    low, high = 0, len(arr)
    while low < high:
        mid = (low + high) // 2
        if arr[mid] < target:
            low = mid + 1
        else:
            high = mid
    return low  

def upper_bound(arr, target):
    low, high = 0, len(arr)
    while low < high:
        mid = (low + high) // 2
        if arr[mid] <= target:
            low = mid + 1
        else:
            high = mid
    return low  

arr = [1, 2, 4, 3, 4, 7, 9]
print("Lower Bound of 4:", lower_bound(arr, 3))  
print("Upper Bound of 4:", upper_bound(arr, 3))
# Out:
# Lower Bound of 4: 2
# Upper Bound of 4: 4

# %%
def first_occurrence(arr, target):
    low, high, ans = 0, len(arr)-1, -1
    while low <= high:
        mid = (low + high) // 2
        if arr[mid] == target:
            ans = mid
            high = mid - 1   
        elif arr[mid] < target:
            low = mid + 1
        else:
            high = mid - 1
    return ans

def last_occurrence(arr, target):
    low, high, ans = 0, len(arr)-1, -1
    while low <= high:
        mid = (low + high) // 2
        if arr[mid] == target:
            ans = mid
            low = mid + 1   
        elif arr[mid] < target:
            low = mid + 1
        else:
            high = mid - 1
    return ans

arr = [1, 2, 4, 3, 4, 3, 7, 9]
print("First Occurrence of 4:", first_occurrence(arr, 3))  
print("Last Occurrence of 4:", last_occurrence(arr, 3))
# Out:
# First Occurrence of 4: 3
# Last Occurrence of 4: 5

# %%
def peak_element(arr):
    low, high = 0, len(arr) - 1
    while low < high:
        mid = (low + high) // 2
        if arr[mid] < arr[mid + 1]:
            low = mid + 1   
        else:
            high = mid     
    return low  

arr = [1, 3, 5, 7, 6, 4, 2]
print("Peak at index:", peak_element(arr))  
print("Peak value:", arr[peak_element(arr)])
# Out:
# Peak at index: 3
# Peak value: 7
